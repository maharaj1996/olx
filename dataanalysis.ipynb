# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.4.0)

# %%
df= pd.read_csv("olxcleaned.csv")

# %%
df
# Out:
#           Make    Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Toyota    Passo  2021        54000  4190000  Petrol      Unregistered
# 1       Suzuki     Ravi  2018        95000  1300000  Petrol           Karachi
# 2       Suzuki    Bolan  2015        50000   800000  Petrol           Karachi
# 3     Daihatsu     Move  2013        94000  2155000  Petrol            Lahore
# 4       Suzuki    Swift  2011       126544  1440000  Petrol           Karachi
# ...        ...      ...   ...          ...      ...     ...               ...
# 9174    Suzuki  Wagon R  2014       115000  2725000  Petrol         Islamabad
# 9175    Suzuki  Wagon R  2017       100000  1850000  Petrol            Lahore
# 9176       KIA  Spectra  2001       123456  1100000  Petrol            Lahore
# 9177    Suzuki     Alto  2009        89000   970000  Petrol            Lahore
# 9178  Daihatsu     Move  2016        95000  2050000  Petrol        Gujranwala
#
#      Car documents  Assembly Transmission  ... Model_Encode Fuel_Encode  \
# 0         Original  Imported    Automatic  ...           44           3
# 1         Original     Local       Manual  ...           47           3
# 2         Original     Local       Manual  ...            4           3
# 3         Original  Imported    Automatic  ...           42           3
# 4         Original     Local       Manual  ...           52           3
# ...            ...       ...          ...  ...          ...         ...
# 9174      Original  Imported    Automatic  ...           55           3
# 9175      Original     Local       Manual  ...           55           3
# 9176      Original  Imported    Automatic  ...           49           3
# 9177      Original  Imported       Manual  ...            2           3
# 9178      Original  Imported    Automatic  ...           42           3
#
#      Registration city_Encode Car documents_Encode  Assembly_Encode  \
# 0                          57                    1                0
# 1                          25                    1                1
# 2                          25                    1                1
# 3                          30                    1                0
# 4                          25                    1                1
# ...                       ...                  ...              ...
# 9174                       21                    1                0
# 9175                       30                    1                1
# 9176                       30                    1                0
# 9177                       30                    1                0
# 9178                       16                    1                0
#
#       Transmission_Encode  Condition_Encode  Seller Location_Encode  \
# 0                       0                 0                      92
# 1                       1                 0                    1399
# 2                       1                 0                    1614
# 3                       0                 0                    1904
# 4                       1                 0                    2447
# ...                   ...               ...                     ...
# 9174                    0                 0                     911
# 9175                    1                 0                    1937
# 9176                    0                 0                    2707
# 9177                    1                 0                    2742
# 9178                    0                 0                    1044
#
#       Description_Encode  Car Features_Encode
# 0                   7369                   46
# 1                   5080                 3192
# 2                   4993                 5970
# 3                   3970                 1247
# 4                   4853                 2835
# ...                  ...                  ...
# 9174                3483                  929
# 9175                8736                 5281
# 9176                7435                 4283
# 9177                4620                 4293
# 9178                8194                  585
#
# [9179 rows x 25 columns]

# %%
lb = LabelEncoder()
feature = {}
for k in df.columns:
    if df[k].dtypes=='O':
        df[str(k)+'_Encode'] = lb.fit_transform(df[k])
        gt = {}
        ke = df[[k,str(k)+'_Encode']].drop_duplicates()[str(k)+'_Encode'].values
        val = df[[k,str(k)+'_Encode']].drop_duplicates()[k].values
        for i in range(len(ke)):
            gt[ke[i]] = val[i]
        feature[k] = gt

# %%
feature
# Out:
# {'Make': {10: 'Toyota',
#   9: 'Suzuki',
#   2: 'Daihatsu',
#   4: 'Honda',
#   5: 'Hyundai',
#   8: 'Mitsubishi',
#   6: 'KIA',
#   0: 'Changan',
#   3: 'FAW',
#   7: 'Mercedes',
#   1: 'Chevrolet'},
#  'Model': {44: 'Passo',
#   47: 'Ravi',
#   4: 'Bolan',
#   42: 'Move',
#   52: 'Swift',
#   55: 'Wagon R',
#   41: 'Mira',
#   8: 'City IDSI',
#   23: 'Cultus VXR',
#   27: 'Every',
#   20: 'Corolla XLI',
#   3: 'Baleno',
#   10: 'City Vario',
#   53: 'Terios Kid',
#   13: 'Civic Prosmetic',
#   9: 'City IVTEC',
#   48: 'Santro',
#   21: 'Corrolla Altis',
#   7: 'City Aspire',
#   38: 'Mehran VXR',
#   24: 'Cuore',
#   43: 'Pajero Mini',
#   45: 'Picanto',
#   2: 'Alto',
#   33: 'Karvaan',
#   56: 'X-PV',
#   30: 'Hijet',
#   26: 'Ek Wagon',
#   1: 'Altis Grande',
#   25: 'E Class',
#   57: 'Yaris',
#   35: 'Lancer',
#   19: 'Corolla GLI',
#   32: 'Joy',
#   12: 'Civic Oriel',
#   16: 'Classic',
#   49: 'Spectra',
#   54: 'V2',
#   40: 'Minicab Bravo',
#   17: 'Corolla Assista',
#   0: 'Alsvin',
#   5: 'C Class',
#   39: 'Minica',
#   29: 'Exclusive',
#   14: 'Civic VTi',
#   6: 'Cervo',
#   50: 'Sportage',
#   18: 'Corolla Axio',
#   28: 'Every Wagon',
#   36: 'Liana',
#   11: 'Civic EXi',
#   51: 'Surf',
#   37: 'Mehran VX',
#   15: 'Civic VTi Oriel',
#   34: 'Khyber',
#   22: 'Cultus VXL',
#   46: 'Prius',
#   31: 'ISIS'},
#  'Fuel': {3: 'Petrol', 0: 'CNG', 2: 'Hybrid', 1: 'Diesel'},
#  'Registration city': {57: 'Unregistered',
#   25: 'Karachi',
#   30: 'Lahore',
#   51: 'Sindh',
#   15: 'Faisalabad',
#   21: 'Islamabad',
#   50: 'Sialkot',
#   16: 'Gujranwala',
#   43: 'Punjab',
#   37: 'Multan',
#   46: 'Rawalpindi',
#   5: 'Bahawalpur',
#   20: 'Hyderabad',
#   45: 'Rahimyar Khan',
#   11: 'Chishtian Mandi',
#   10: 'Chiniot',
#   60: 'Wazirabad',
#   47: 'Sahiwal',
#   17: 'Gujrat',
#   0: 'Abbottabad',
#   27: 'Khanewal',
#   41: 'Peshawar',
#   48: 'Sargodha',
#   6: 'Bannu',
#   39: 'Nowshera',
#   26: 'Kasur',
#   1: 'Arifwala',
#   23: 'Jhang Sadar',
#   13: 'Dera Ghazi Khan',
#   33: 'Mardan',
#   2: 'Attock',
#   31: 'Larkana',
#   56: 'Unknown',
#   24: 'Jhelum',
#   28: 'Khanpur',
#   59: 'Wah',
#   40: 'Okara',
#   7: 'Bhakkar',
#   49: 'Sheikhüpura',
#   54: 'Swat',
#   14: 'Dera Ismail Khan',
#   29: 'Khushab',
#   8: 'Bhimber',
#   32: 'Mansehra',
#   35: 'Mirpur',
#   44: 'Quetta',
#   58: 'Vehari',
#   18: 'Hafizabad',
#   9: 'Charsadda',
#   55: 'Toba Tek singh',
#   22: 'Jaranwala',
#   42: 'Pirmahal',
#   19: 'Haripur',
#   36: 'Mirpur Khas',
#   4: 'Bahawalnagar',
#   53: 'Swabi',
#   12: 'Dadu',
#   34: 'Mianwali',
#   52: 'Sukkar',
#   3: 'Badin',
#   38: 'Nawabshah'},
#  'Car documents': {1: 'Original', 0: 'Duplicate'},
#  'Assembly': {0: 'Imported', 1: 'Local'},
#  'Transmission': {0: 'Automatic', 1: 'Manual'},
#  'Condition': {0: 'Used'},
#  'Seller Location': {92: 'Airline Avenue, Islamabad',
#   1399: 'Kahuta, Rawalpindi',
#   1614: 'Lyari Expressway, Karachi',
#   1904: 'New Amir Town, Lahore',
#   2447: 'Shadman 2, Karachi',
#   39: 'Abbot Road, Sialkot',
#   1963: 'North Nazimabad - Block A, Karachi',
#   1513: 'Korangi Industrial Area, Karachi',
#   195: 'Allama Iqbal Town - Huma Block, Lahore',
#   143: 'Al Najaf Colony, Faisalabad',
#   2344: 'Saddar, Rawalpindi',
#   1933: 'New Northern Bypass, Chakwal',
#   175: 'Ali Town, Mirpur Khas',
#   2758: 'Zaman Villas, Bahawalpur',
#   1516: 'Kot Abdul Malik, Sheikhüpura',
#   2263: 'Raiwind Bypass, Raiwind',
#   676: 'DHA Phase 1, Lahore',
#   2074: 'Others, Sadiqabad',
#   1457: 'Khaizi, Quetta',
#   652: 'D-12, Islamabad',
#   2663: 'Topi, Swabi',
#   1320: 'Jamshed Road, Karachi',
#   2689: 'Usman Colony, Gujranwala',
#   2043: 'Others, Karachi',
#   1936: 'New Samanabad, Lahore',
#   2666: 'Township - Sector A2, Lahore',
#   1053: 'Gul Colony, Lahore',
#   1666: 'Mamunkanjan, Faisalabad',
#   1133: 'Gulshan-e-Iqbal, Karachi',
#   1753: 'Misryal Road, Rawalpindi',
#   1970: 'North Nazimabad, Karachi',
#   2330: 'Saadi Town, Karachi',
#   14: '7th Avenue, Islamabad',
#   248: 'Askari 11, Lahore',
#   884: 'Federal B Area - Block 22, Karachi',
#   2287: 'Rawat Enclave, Rawalpindi',
#   200: 'Allama Iqbal Town, Lahore',
#   2430: 'Scheme 33, Karachi',
#   1140: 'Gulshan-e-Maymar, Karachi',
#   1706: 'Marghzar Officers Colony, Lahore',
#   1639: 'Madni Park Town, Pirmahal',
#   1573: 'Lalazar, Rawalpindi',
#   588: 'Chungi No. 5, Kabirwala',
#   1962: 'North Karachi, Karachi',
#   2028: 'Others, Gujranwala',
#   1785: 'Mohammad Ali Jinnah Road, Okara',
#   1760: 'Model Town - Block R, Lahore',
#   738: 'Dhok Abdullah, Jhelum',
#   2484: 'Shahra-e-Faisal, Karachi',
#   2453: 'Shah Faisal Town, Karachi',
#   1588: 'Latifabad Unit 8, Hyderabad',
#   1459: 'Khalid Bin Walid Road, Karachi',
#   619: 'Clifton - Block 7, Karachi',
#   1801: 'Motorway Chowk, Islamabad',
#   2253: 'Rahwali Cantt, Gujranwala',
#   495: 'Cantt, Rawalpindi',
#   686: 'DHA Phase 6, Lahore',
#   2176: 'Peshawar Road, Rawalpindi',
#   1239: 'Hyderabad Road, Mirpur Khas',
#   501: 'Cavalry Ground, Lahore',
#   720: 'Defence View Phase 2, Karachi',
#   2165: 'Pechs I, Karachi',
#   1141: 'Gulshan-e-Mehfooz Housing Society, Sahiwal',
#   439: 'Buffer Zone 1, Karachi',
#   230: 'Asghar Mall Road, Rawalpindi',
#   842: 'Faizabad, Rawalpindi',
#   865: 'Fateh Garh, Lahore',
#   349: 'Bahria Town, Islamabad',
#   447: 'Burma Town, Islamabad',
#   1871: 'National Police Foundation O-9, Islamabad',
#   231: 'Asghar Mall Scheme, Rawalpindi',
#   505: 'Chah Hafiz Wala, Multan',
#   2200: 'Punjab Chowrangi, Karachi',
#   1234: 'Hussainabad, Hyderabad',
#   166: 'Alfalah Town, Lahore',
#   219: 'Ancholi, Karachi',
#   1772: 'Model Town, Lahore',
#   2342: 'Saddar, Lahore',
#   1243: 'I-10, Islamabad',
#   2335: 'Sabzazar, Lahore',
#   1807: 'Mughalpura, Lahore',
#   2137: 'Palm City Housing Scheme, Gujranwala',
#   2445: 'Shadbagh, Lahore',
#   1196: 'Haroonabad, Bahawalnagar',
#   2635: 'Tariq Road, Karachi',
#   2112: 'PWD Road, Islamabad',
#   1938: 'New Shah Shams Colony, Multan',
#   1629: 'MPCHS - Multi Gardens, Islamabad',
#   604: 'Citizen Road, Hyderabad',
#   2025: 'Others, Faisalabad',
#   2683: 'University Road, Karachi',
#   1061: 'Gulberg 3, Lahore',
#   1752: 'Misri Shah, Lahore',
#   1100: 'Gulistan-e-Jauhar Block 2, Karachi',
#   389: 'Bhagatpura, Lahore',
#   1152: 'Gulzar-E-Hijri, Karachi',
#   419: 'Block 10, Dera Ghazi Khan',
#   2737: 'Westridge, Rawalpindi',
#   2669: 'Township - Sector C1, Lahore',
#   111: 'Ajwa Residencia, Renala Khurd',
#   675: 'DHA Phase 1, Karachi',
#   670: 'DHA Defence, Gujranwala',
#   487: 'Cantt, Lahore',
#   1251: 'I.I. Chundrigar Road, Karachi',
#   1416: 'Kamran Chowrangi, Karachi',
#   719: 'Defence Road, Sialkot',
#   1108: 'Gulistan-e-Jauhar, Karachi',
#   1740: 'Military Accounts Housing Society, Lahore',
#   1601: 'Light House, Karachi',
#   578: 'Chowk Kumharanwala, Multan',
#   840: 'Faisalabad, Punjab',
#   1489: 'Khurianwala, Faisalabad',
#   1763: 'Model Town C, Bahawalpur',
#   2539: 'Sialkot Road, Gujranwala',
#   1660: 'Malir Cantonment, Karachi',
#   2512: 'Sheikh Basti, Okara',
#   106: 'Airport Road, Sialkot',
#   1192: 'Harbanspura, Lahore',
#   561: 'Chenab Rangers Road, Sialkot',
#   1294: 'Jada, Jhelum',
#   2688: 'Urdu Bazar, Lahore',
#   1948: 'Nishatabad, Faisalabad',
#   1250: 'I-9, Islamabad',
#   1008: 'Ghulam Mohammad Abad, Faisalabad',
#   2273: 'Rangpura Road, Sialkot',
#   1051: 'Gul Abad, Lower Dir',
#   1240: 'Hyderabad, Sindh',
#   2341: 'Saddar, Karachi',
#   2247: 'Rahatabad, Peshawar',
#   864: 'Fateh Garh Town, Sialkot',
#   2697: 'Victoria Park, Lahore',
#   56: 'Abdullah Heaven, Hyderabad',
#   2682: 'University Chowk, Bahawalpur',
#   1127: 'Gulshan-E-Hadeed, Karachi',
#   2724: 'Wapda Town, Lahore',
#   1086: 'Gulistan-e-Jauhar - Block 16-A, Karachi',
#   957: 'GT Road, Wah',
#   2105: 'PIA Cooperative Officers Housing Society, Rawalpindi',
#   1663: 'Malir, Karachi',
#   2246: 'Rafi Gardens, Sahiwal',
#   1136: 'Gulshan-e-Kaneez Fatima, Karachi',
#   1792: 'Mohlanwal, Lahore',
#   813: 'F-11 Markaz, Islamabad',
#   1386: 'KLP Road, Sadiqabad',
#   931: 'G-9, Islamabad',
#   1247: 'I-14, Islamabad',
#   1166: 'Habib Colony, Sheikhüpura',
#   1049: 'Gujrat Bypass, Gujrat',
#   2382: 'Sambrial, Sialkot',
#   673: 'DHA Defence, Lahore',
#   601: 'Citi Housing Society - Block B, Sialkot',
#   973: 'Garden Town, Multan',
#   592: 'Circular Road, Daska',
#   2289: 'Rawat, Islamabad',
#   292: 'B-17, Islamabad',
#   2220: 'Qasimabad Phase 2, Hyderabad',
#   199: 'Allama Iqbal Town, Karachi',
#   274: 'Awan Town, Lahore',
#   2486: 'Shahra-e-Qaideen, Karachi',
#   1099: 'Gulistan-e-Jauhar Block 19, Karachi',
#   2718: 'Wapda Town Phase 1, Lahore',
#   493: 'Cantt, Peshawar',
#   2306: 'Rifah Aam, Karachi',
#   1838: 'Muslim Town, Faisalabad',
#   2368: 'Saima Arabian Villas, Karachi',
#   820: 'F-6 Markaz, Islamabad',
#   680: 'DHA Phase 3, Lahore',
#   905: 'G-11, Islamabad',
#   1040: 'Green Town, Lahore',
#   2193: 'Police Foundation Housing Scheme, Rawalpindi',
#   2508: 'Sharaqpur Sharif, Sheikhüpura',
#   535: 'Chaklala Scheme, Rawalpindi',
#   735: 'Dharampura, Lahore',
#   1819: 'Multan Road, Pattoki',
#   1290: 'Izmir Town Extension, Lahore',
#   611: 'Civil Lines, Gujranwala',
#   1119: 'Gulshan Ali Housing Scheme, Sahiwal',
#   684: 'DHA Phase 5, Lahore',
#   911: 'G-13, Islamabad',
#   2102: 'PGECHS Phase 1, Lahore',
#   2498: 'Shamasabad Colony, Multan',
#   1728: 'Memon Colony, Tando Muhammad Khan',
#   2084: 'Others, Tando Adam',
#   2073: 'Others, Renala Khurd',
#   494: 'Cantt, Quetta',
#   372: 'Baseline Road, Gojra',
#   1319: 'Jamshed Quarters, Karachi',
#   1334: 'Javed Bahria Coopretive Housing Society, Karachi',
#   1164: 'HBCHS - Haroon Bahria Society, Karachi',
#   138: 'Al Jalil Garden, Lahore',
#   266: 'Attock Road, Attock',
#   202: 'Allied City & Market, Faisalabad',
#   1797: 'Mominabad, Karachi',
#   1885: 'Nawansher, Abbottabad',
#   1090: 'Gulistan-e-Jauhar Block 10, Karachi',
#   821: 'F-6, Islamabad',
#   2540: 'Sialkot, Punjab',
#   657: 'DC Office Road, Layyah',
#   1372: 'Johar Town, Lahore',
#   643: 'Combo Colony, Lahore',
#   2069: 'Others, Pattoki',
#   2587: 'Sukkur, Sindh',
#   347: 'Bahria Town Phase 8, Rawalpindi',
#   773: 'Dream Land Housing Society, Chishtian Mandi',
#   731: 'Dera Ghazi Khan, Punjab',
#   1842: 'Mustafa Town, Lahore',
#   1208: 'Havelian, Abbottabad',
#   1937: 'New Satellite Town, Sargodha',
#   955: 'GT Road, Sarai Alamgir',
#   2390: 'Sanda, Lahore',
#   1366: 'Jinnah Town, Multan',
#   941: 'GT Road, Gujrat',
#   355: 'Baldia Town, Karachi',
#   1370: 'Johar Town Phase 1, Lahore',
#   682: 'DHA Phase 4, Lahore',
#   361: 'Bani Gala, Islamabad',
#   1610: 'Lucknow Society, Karachi',
#   1344: 'Jhang City, Jhang',
#   2685: 'University Road, Sargodha',
#   290: 'Azizabad, Karachi',
#   2087: 'Others, Toba Tek singh',
#   1323: 'Jand, Attock',
#   1498: 'Kohat Road, Peshawar',
#   346: 'Bahria Town Phase 7, Rawalpindi',
#   1863: 'Naseerabad, Rawalpindi',
#   702: 'Daroghewala, Lahore',
#   888: 'Federal B Area, Karachi',
#   904: 'G-10, Islamabad',
#   624: 'Clifton, Karachi',
#   1826: 'Murad Memon Goth, Karachi',
#   903: 'G Magnolia Park, Gujranwala',
#   2243: 'Race Course, Rawalpindi',
#   427: 'Block K, Burewala',
#   975: 'Garden West, Karachi',
#   2489: 'Shalamar Town, Lahore',
#   1849: 'NFC 1, Lahore',
#   1512: 'Korangi Creek Cantonment, Karachi',
#   2423: 'Scheme 33 - Sector 16-A, Karachi',
#   2170: 'Peoples Colony No 1, Faisalabad',
#   1803: 'Motorway Valley, Faisalabad',
#   461: 'Canal Expressway, Faisalabad',
#   1371: 'Johar Town Phase 2, Lahore',
#   827: 'Factory Area, Faisalabad',
#   2461: 'Shah Rukn-e-Alam Colony, Multan',
#   73: 'Adiala Road, Rawalpindi',
#   1696: 'Manzoor Colony, Karachi',
#   81: 'Agrics Town, Lahore',
#   2154: 'Park View Villas, Lahore',
#   1901: 'Nespak Scheme Phase 1, Lahore',
#   1744: 'Millat Town, Faisalabad',
#   551: 'Chaprar Road, Sialkot',
#   664: 'DHA City Karachi, Karachi',
#   2107: 'PIA Housing Scheme, Lahore',
#   2427: 'Scheme 33 - Sector 38-A, Karachi',
#   1523: 'Kot Momin, Sargodha',
#   440: 'Buffer Zone 2, Karachi',
#   721: 'Defence View Society, Karachi',
#   1174: 'Haji Chowk, Rawalpindi',
#   272: 'Awami Villas, Dera Ismail Khan',
#   570: 'Chinioti Road, Chiniot',
#   1257: 'Ichhra, Lahore',
#   927: 'G-7, Islamabad',
#   521: 'Chak 8 DNB, Bahawalpur',
#   1348: 'Jhang Road, Muzaffargarh',
#   1835: 'Muslim City, Peshawar',
#   2396: 'Saqib Town, Lahore',
#   2420: 'Satiana Road, Faisalabad',
#   2533: 'Shoukat Town, Lahore',
#   497: 'Cantt, Sialkot',
#   596: 'Circular Road, Sialkot',
#   2010: 'Others, Bannu',
#   1117: 'Gulshan Abad, Rawalpindi',
#   454: 'Canal Bank Housing Scheme, Lahore',
#   672: 'DHA Defence, Karachi',
#   2082: 'Others, Sukkur',
#   17: 'A-One City, Quetta',
#   459: 'Canal Colony, Hafizabad',
#   2736: 'Wazirabad Road, Wazirabad',
#   8: '24 Block, Sargodha',
#   2284: 'Rawalpindi Road, Chakwal',
#   178: 'Ali View Garden - Phase 3, Lahore',
#   1131: 'Gulshan-e-Habib, Faisalabad',
#   2671: 'Township, Lahore',
#   208: 'Amarpura, Rawalpindi',
#   2182: 'Pindi Bypass, Gujranwala',
#   2723: 'Wapda Town, Gujranwala',
#   2250: 'Rahim Yar Khan Bypass, Rahimyar Khan',
#   636: 'College Road, Pakpattan',
#   1160: 'H-13, Islamabad',
#   916: 'G-15 Markaz, Islamabad',
#   12: '40 Feet Road, Multan',
#   2003: 'Orangi Town, Karachi',
#   491: 'Cantt, Okara',
#   1973: 'Nowshera Road, Gujranwala',
#   315: 'Bahari Colony, Sheikhüpura',
#   1503: 'Kohinoor Town, Faisalabad',
#   1917: 'New Hyderabad City, Hyderabad',
#   1882: 'Nawab Town, Lahore',
#   1283: 'Ismail City, Faisalabad',
#   1316: 'Jampur Road, Dera Ghazi Khan',
#   1590: 'Latifabad, Hyderabad',
#   4: '12th Avenue, Islamabad',
#   2570: 'Sohawa, Jhelum',
#   1420: 'Karachi - Hyderabad Motorway, Hyderabad',
#   2757: 'Zaman Town, Karachi',
#   972: 'Garden Town, Lahore',
#   2633: 'Tariq Colony, Lahore',
#   2703: 'Wah Cantt, Wah',
#   806: 'Eminabad More, Gujranwala',
#   294: 'BOR Board of Revenue Housing Society, Lahore',
#   695: 'Daharki, Sindh',
#   733: 'Dhamyal Road, Rawalpindi',
#   999: 'Ghauri Town, Islamabad',
#   2124: 'Pak Ideal Cooperative Housing Society, Karachi',
#   1077: 'Guldasht Town, Lahore',
#   1890: 'Nazar Mohalla, Larkana',
#   379: 'Batagram, Khyber Pakhtunkhwa',
#   2276: 'Rashid Colony, Gujrat',
#   287: 'Aziz Bhatti Shaheed Road, Sialkot',
#   1404: 'Kalabagh - Nathia Gali, Galyat',
#   2668: 'Township - Sector B2, Lahore',
#   238: 'Ashraf Town, Chakwal',
#   2433: 'Sector 21-E, Wah',
#   1651: 'Main Qasimabad Road, Hyderabad',
#   1886: 'Nawaz Sharif Housing Scheme, Karachi',
#   1263: 'Indus Highway, Karak',
#   1211: 'Hayatabad Phase 1, Peshawar',
#   1084: 'Gulistan Colony, Rawalpindi',
#   1132: 'Gulshan-e-Iqbal Town, Karachi',
#   1773: 'Model Town, Mandi Bahauddin',
#   2132: 'Pakpattan Road, Sahiwal',
#   2096: 'PAF Road, Sargodha',
#   1952: 'Noor Garden, Okara',
#   2290: 'Raza Abad, Faisalabad',
#   329: 'Bahria Orchard Phase 2, Lahore',
#   2023: 'Others, Dera Ghazi Khan',
#   2252: 'Rahimyar Khan, Punjab',
#   1024: 'Golra Mor, Islamabad',
#   2518: 'Sheikhüpura, Punjab',
#   1397: 'Kahna, Lahore',
#   1249: 'I-8, Islamabad',
#   1701: 'Mardan, Khyber Pakhtunkhwa',
#   2576: 'Stadium Road, Karachi',
#   2468: 'Shahdara, Lahore',
#   1645: 'Mailsi Trade Center, Mailsi',
#   2: '100 Ft Road, Sukkur',
#   353: 'Baldia Road, Bahawalnagar',
#   1482: 'Khayaban-e-Amin, Lahore',
#   690: 'DHA Phase 8, Karachi',
#   2653: 'Thokar Niaz Baig, Lahore',
#   1072: 'Gulberg Town, Mirpur Khas',
#   225: 'Architects Engineers Society - Block F, Lahore',
#   2272: 'Range Road, Rawalpindi',
#   1248: 'I-8 Markaz, Islamabad',
#   1631: 'Madina Colony, Karachi',
#   1120: 'Gulshan Dadan, Rawalpindi',
#   1105: 'Gulistan-e-Jauhar Block 7, Karachi',
#   2062: 'Others, Muzaffargarh',
#   1832: 'Murree Road, Rawalpindi',
#   977: 'Garhi Shahu, Lahore',
#   772: 'Dream Gardens, Lahore',
#   2202: 'Punjab Coop Housing Society, Lahore',
#   2171: 'Peoples Colony No 2, Faisalabad',
#   323: 'Bahria Enclave 2, Islamabad',
#   418: 'Bismillah Housing Scheme, Lahore',
#   536: 'Chaklala, Rawalpindi',
#   799: 'Eden Villas, Lahore',
#   1415: 'Kamra, Attock',
#   2729: 'Warsak Road, Peshawar',
#   38: 'Abbot Road, Lahore',
#   1628: 'MM Road, Muzaffargarh',
#   890: 'Ferozepur Road, Lahore',
#   709: 'Dastgir Colony, Karachi',
#   276: 'Ayub Colony, Rawalpindi',
#   2525: 'Shergarh, Mardan',
#   2418: 'Satellite Town, Rawalpindi',
#   1547: 'Lahore Bypass, Lahore',
#   2214: 'Qainchi Mor, Sargodha',
#   595: 'Circular Road, Narowal',
#   1833: 'Murtaza Chorangi Landhi No 4, Karachi',
#   1082: 'Gulistan Colony No 1, Faisalabad',
#   2714: 'Wapda City, Gujranwala',
#   1271: 'Iqbal Town, Sialkot',
#   1966: 'North Nazimabad - Block H, Karachi',
#   1401: 'Kala Board, Karachi',
#   2277: 'Rashid Minhas Road, Karachi',
#   1766: 'Model Town Link Road, Lahore',
#   2129: 'Pakpattan Bypass, Pakpattan',
#   1951: 'Nizamabad, Lahore',
#   1014: 'Gohadpur, Sialkot',
#   2051: 'Others, Lala Musa',
#   775: 'Dubai Town, Lahore',
#   16: '9th Avenue, Islamabad',
#   218: 'Anarkali, Lahore',
#   1923: 'New Karachi, Karachi',
#   2181: 'Pindi Bhattian - Faisalabad Motorway, Pindi Bhattian',
#   637: 'College Road, Rawalpindi',
#   1994: 'Old Chichawatni, Chichawatni',
#   908: 'G-11/4, Islamabad',
#   384: 'Begampura, Lahore',
#   876: 'Fazaia Colony, Rawalpindi',
#   1869: 'Natha Khan Goth, Karachi',
#   273: 'Awan Sharif Road, Barnala(Azad Kashmir)',
#   1852: 'Nain Sukh, Lahore',
#   2355: 'Saeedabad, Karachi',
#   571: 'Chishti Nagar, Karachi',
#   862: 'Farooqabad, Sheikhüpura',
#   2457: 'Shah Kamal, Lahore',
#   1735: 'Mian Colony, Lahore',
#   107: 'Airport, Karachi',
#   920: 'G-5, Islamabad',
#   97: 'Airport Housing Society, Rawalpindi',
#   119: 'Akhtar Colony, Karachi',
#   1830: 'Murree Road, Abbottabad',
#   1993: 'Okara, Punjab',
#   1906: 'New Chakwal City, Chakwal',
#   1719: 'Mattital Road, Multan',
#   2088: 'Others, Vehari',
#   1418: 'Kangniwala, Gujranwala',
#   504: 'Central Park Housing Scheme, Lahore',
#   403: 'Bhutta Village, Karachi',
#   345: 'Bahria Town Phase 4, Rawalpindi',
#   1241: 'Hyderi, Karachi',
#   2565: 'Soan Garden, Islamabad',
#   1505: 'Kohsar Colony, Taxila',
#   220: 'Anda Mor Road, Karachi',
#   550: 'Chapal Courtyard, Karachi',
#   103: 'Airport Road, Quetta',
#   7: '204 Chak Road, Faisalabad',
#   87: 'Ahmedpur Road, Bahawalpur',
#   1332: 'Jaranwala, Faisalabad',
#   728: 'Depalpur Road, Okara',
#   555: 'Chatha Bakhtawar, Islamabad',
#   777: 'E-10, Islamabad',
#   1347: 'Jhang Road, Faisalabad',
#   712: 'Davis Road, Lahore',
#   2092: 'P & D Housing Society, Lahore',
#   1984: 'Officer Colony, Rawalpindi',
#   1341: 'Jhanda Chichi, Rawalpindi',
#   2684: 'University Road, Peshawar',
#   1987: 'Oghi Road, Mansehra',
#   1259: 'Ilahi Abad, Faisalabad',
#   338: 'Bahria Town - Sector D, Lahore',
#   2648: 'Thanda Pani, Islamabad',
#   126: 'Al Faisal Town, Lahore',
#   395: 'Bhekopur, Gujranwala',
#   246: 'Askari 10, Lahore',
#   924: 'G-6, Islamabad',
#   2093: 'P.I.B. Colony, Karachi',
#   1411: 'Kalma Chowk, Lahore',
#   68: 'Abul Hassan Isphani Road, Karachi',
#   2177: 'Peshawar, Khyber Pakhtunkhwa',
#   348: 'Bahria Town Rawalpindi, Rawalpindi',
#   2015: 'Others, Chakwal',
#   1655: 'Malakwal, Mandi Bahauddin',
#   2125: 'Pakistan',
#   2098: 'PASSCO Housing Society, Lahore',
#   1346: 'Jhang Road, Chiniot',
#   1462: 'Khanewal - Kabir Wala Road, Jhang',
#   2001: 'Omega Residencia, Lahore',
#   1691: 'Mansehra International College Road, Mansehra',
#   1922: 'New Karachi - Sector 5-I, Karachi',
#   350: 'Bahria Town, Lahore',
#   1377: 'Journalists Colony, Hyderabad',
#   42: 'Abbottabad Road, Abbottabad',
#   2760: 'Zarghun Road, Quetta',
#   2572: 'Spinny Road, Quetta',
#   1337: 'Jeewan Avenue, Sahiwal',
#   324: 'Bahria Enclave, Islamabad',
#   1514: 'Korangi Road, Karachi',
#   2008: 'Others, Bahawalpur',
#   1964: 'North Nazimabad - Block B, Karachi',
#   270: 'Auto Bhan Road, Hyderabad',
#   2294: 'Rehana, Haripur',
#   152: 'Al Rehman Garden Phase 3, Lahore',
#   896: 'Fort Abbas, Bahawalnagar',
#   1515: 'Korangi, Karachi',
#   1902: 'Nespak Scheme Phase 3, Lahore',
#   192: 'Allama Iqbal Road, Lahore',
#   1098: 'Gulistan-e-Jauhar Block 18, Karachi',
#   1417: 'Kanganpur, Kasur',
#   432: 'Bosan Road, Multan',
#   1765: 'Model Town Extension, Lahore',
#   1362: 'Jinnah Colony, Rawalpindi',
#   2422: 'Scheme 33 - Sector 15-A, Karachi',
#   2226: 'Qayyumabad, Karachi',
#   1894: 'Nazimabad 4, Karachi',
#   681: 'DHA Phase 4, Karachi',
#   429: 'Blue Area, Islamabad',
#   1680: 'Manga - Raiwind Road, Raiwind',
#   96: 'Airport Enclave, Islamabad',
#   2395: 'Sant Nagar, Lahore',
#   1353: 'Jhangi Syedan, Abbottabad',
#   1444: 'Katchery Bazar, Faisalabad',
#   1433: 'Kas Koroona, Mardan',
#   436: 'Buch Executive Villas, Multan',
#   386: 'Behar Colony, Karachi',
#   298: 'Babar Colony, Rawalpindi',
#   988: 'Ghang Road, Sheikhüpura',
#   1876: 'Navy Housing Scheme Karsaz Phase-2, Karachi',
#   1288: 'Ittifaq Town, Lahore',
#   659: 'DG Khan Road, Muzaffargarh',
#   1193: 'Harley Street, Rawalpindi',
#   2735: 'Wazirabad Road, Sialkot',
#   251: 'Askari 14, Rawalpindi',
#   2190: 'Pir Pai Road, Nowshera',
#   2283: 'Rawal Road, Rawalpindi',
#   311: 'Bahadurabad, Karachi',
#   435: 'British Homes Colony, Islamabad',
#   2179: 'Phul Ghulab Road, Abbottabad',
#   1713: 'Maskan Chowrangi, Karachi',
#   2573: 'Stadium Park, Sheikhüpura',
#   1286: 'Ittehad Colony, Lahore',
#   1492: 'Khushab Road, Sargodha',
#   288: 'Aziz Bhatti Town, Sargodha',
#   739: 'Dhok Babu Irfan, Rawalpindi',
#   1092: 'Gulistan-e-Jauhar Block 12, Karachi',
#   1097: 'Gulistan-e-Jauhar Block 17, Karachi',
#   241: 'Asia Housing Scheme, Rawalpindi',
#   2044: 'Others, Karak',
#   2547: 'Sindh Cooperative Housing Society, Sukkur',
#   2221: 'Qasimabad, Hyderabad',
#   2281: 'Ravi Road, Okara',
#   1722: 'Mayo Hospital Road, Lahore',
#   1608: 'Loralai, Balochistan',
#   1724: 'Mehar Fiaz Colony, Lahore',
#   2692: 'Valencia Town, Lahore',
#   420: 'Block 25, Dera Ghazi Khan',
#   746: 'Dhok Sayedan Road, Rawalpindi',
#   1078: 'Gulfishan Colony, Faisalabad',
#   1960: 'North Karachi - Sector 5-C, Karachi',
#   663: 'DHA 9 Town, Lahore',
#   1553: 'Lahore Motorway City, Lahore',
#   210: 'Ameen Town - Phase 1, Dera Ghazi Khan',
#   1897: 'Nazimabad, Karachi',
#   1754: 'Mithadar, Karachi',
#   2071: 'Others, Rahimyar Khan',
#   1429: 'Karim Park, Lahore',
#   2615: 'Taj Bagh, Lahore',
#   874: 'Fatima Jinnah Town, Multan',
#   812: 'F-10, Islamabad',
#   2078: 'Others, Sargodha',
#   1759: 'Model Colony, Rawalpindi',
#   1134: 'Gulshan-e-Iqbal, Rahimyar Khan',
#   667: 'DHA Defence Phase 1, Islamabad',
#   1913: 'New Ghalla Mandi, Khanpur',
#   1356: 'Jhelum Road, Chakwal',
#   1855: 'Nanak Wara, Karachi',
#   1519: 'Kot Fareed Road, Sargodha',
#   1887: 'Naya Nazimabad, Karachi',
#   1333: 'Jauharabad Road, Khushab',
#   677: 'DHA Phase 2 Extension, Karachi',
#   1702: 'Margalla Town, Islamabad',
#   1982: 'OPF Housing Scheme, Lahore',
#   1378: 'Jubilee Town, Lahore',
#   1571: 'Lalazar Colony, Wah',
#   2101: 'PECHS, Karachi',
#   575: 'Chota Lahor, Swabi',
#   2762: 'Zeeshan Colony, Kamalia',
#   1047: 'Gujrat - Fatehpur Road, Gujrat',
#   1967: 'North Nazimabad - Block L, Karachi',
#   129: 'Al Falah Society, Karachi',
#   732: 'Dera Ismail Khan, Khyber Pakhtunkhwa',
#   2621: 'Talagang Road, Chakwal',
#   1816: 'Multan Road, Lahore',
#   2670: 'Township - Sector C2, Lahore',
#   940: 'GT Road, Gujranwala',
#   2014: 'Others, Burewala',
#   486: 'Cantt, Kharian',
#   2640: 'Taxila, Punjab',
#   55: 'Abdullah Haroon Road, Karachi',
#   1768: 'Model Town, Gujranwala',
#   1268: 'Iqbal Road, Abbottabad',
#   1059: 'Gulberg 1, Lahore',
#   1662: 'Malir Link To Super Highway, Karachi',
#   2300: 'Rehmanpura (Ferozpur Road), Lahore',
#   2238: 'Qurban Line, Lahore',
#   1598: 'Liaquatabad, Karachi',
#   221: 'Ansar Colony, Multan',
#   415: 'Bin Qasim Town, Karachi',
#   1841: 'Muslimabad Society, Karachi',
#   307: 'Baghbanpura, Lahore',
#   2172: 'Peoples Colony, Gujranwala',
#   2100: 'PCSIR Staff Colony, Lahore',
#   1142: 'Gulshan-e-Ravi, Lahore',
#   1893: 'Nazimabad 3, Karachi',
#   1562: 'Lake City, Lahore',
#   1095: 'Gulistan-e-Jauhar Block 15, Karachi',
#   1821: 'Multan, Punjab',
#   569: 'Chiniot Jhumra Road, Chiniot',
#   2606: 'Swami Nagar, Lahore',
#   965: 'Gajju Matah, Lahore',
#   484: 'Cantt, Jhelum',
#   2354: 'Saeed Park, Lahore',
#   620: 'Clifton - Block 8, Karachi',
#   2601: 'Surjani Town, Karachi',
#   1321: 'Jamshed Town, Karachi',
#   557: 'Chauburji, Lahore',
#   1861: 'Naseem Nagar Road, Hyderabad',
#   1150: 'Gulshan-e-Zafar Colony, Muridike',
#   383: 'Bedian Road, Lahore',
#   2034: 'Others, Hasilpur',
#   1093: 'Gulistan-e-Jauhar Block 13, Karachi',
#   1884: 'Nawabshah Road, Sanghar',
#   2577: 'State Bank of Pakistan Staff Co-Operative Housing Society, Karachi',
#   1252: 'IEP Engineers Town - Sector A, Lahore',
#   797: 'Eden Valley, Faisalabad',
#   1743: 'Millat Road, Faisalabad',
#   2515: 'Sheikh Maltoon Town, Mardan',
#   1912: 'New Garden Town, Lahore',
#   722: 'Defence, Hyderabad',
#   819: 'F-5, Islamabad',
#   247: 'Askari 10, Rawalpindi',
#   2444: 'Shadab Town, Sahiwal',
#   492: 'Cantt, Pasrur',
#   2470: 'Shaheed Millat Road, Karachi',
#   1794: 'Moinabad, Karachi',
#   942: 'GT Road, Hasan Abdal',
#   623: 'Clifton Township, Rawalpindi',
#   82: 'Ahbab Housing Society, Lahore',
#   1000: 'Ghauri Town, Rawalpindi',
#   1374: 'Johi, Dadu',
#   800: 'Eden, Lahore',
#   159: 'Al-Manzar Society, Karachi',
#   1041: 'Green Town, Pakpattan',
#   201: 'Allama Iqbal Town, Rahimyar Khan',
#   2456: 'Shah Jamal, Lahore',
#   1700: 'Mardan Road, Charsadda',
#   1990: 'Okara Road, Depalpur',
#   1468: 'Khanpur Road, Rahimyar Khan',
#   1458: 'Khalabat Township, Haripur',
#   1526: 'Kot Radha Kishan, Kasur',
#   398: 'Bhimber Road, Gujrat',
#   964: 'Gadwaal Road, Wah',
#   674: 'DHA Defence, Multan',
#   2634: 'Tariq Gardens, Lahore',
#   423: 'Block 47, Dera Ghazi Khan',
#   1085: 'Gulistan-e-Jauhar - Block 10-A, Karachi',
#   584: 'Chungi No 1, Multan',
#   1511: 'Korangi - Sector 48-F1, Karachi',
#   901: 'Frash Town, Islamabad',
#   2704: 'Wah, Punjab',
#   1619: 'MA Jinnah Road, Multan',
#   811: 'F-10 Markaz, Islamabad',
#   2435: 'Sector F-2, Mirpur',
#   437: 'Buddi Chowk, Hyderabad',
#   244: 'Asim Town, Lahore',
#   83: 'Ahmad Abad, Rawalpindi',
#   2057: 'Others, Mianwali',
#   2288: 'Rawat Industrial Estate, Rawalpindi',
#   1496: 'Kohat - Hangu Road, Kohat',
#   303: 'Bagarian, Lahore',
#   1087: 'Gulistan-e-Jauhar - Block 3-A, Karachi',
#   691: 'DHA Phase 8, Lahore',
#   93: 'Airline Housing Society, Lahore',
#   1944: 'Nisar Colony, Faisalabad',
#   358: 'Baloch Colony, Karachi',
#   2676: 'UK Garden, Pirmahal',
#   278: 'Azadi Chowk, Lahore',
#   1942: 'New Westridge, Rawalpindi',
#   490: 'Cantt, Nowshera',
#   2143: 'Pano Akil, Sukkur',
#   2195: 'Police Lines 1, Multan',
#   1891: 'Nazimabad 1, Karachi',
#   1839: 'Muslim Town, Lahore',
#   59: 'Abdullahpur, Faisalabad',
#   1681: 'Manga Mandi, Lahore',
#   2118: 'Pak Arab Fertilizer Housing Colony, Multan',
#   448: 'Buttar, Sialkot',
#   2439: 'Sewara Chowk, Multan',
#   1931: 'New Multan, Multan',
#   1941: 'New Taqbeer Homes, Lahore',
#   2282: 'Ravi Town, Khanpur',
#   2437: 'Senate Secretariat Employees Cooperative Housing Society, Islamabad',
#   565: 'Chichawatni to Rajana Road, Toba Tek singh',
#   2083: 'Others, Swabi',
#   1621: 'MBCHS - Makhdoom Bilawal Society, Karachi',
#   1030: 'Grand Avenues Housing Scheme, Lahore',
#   407: 'Bilal Colony, Khanewal',
#   516: 'Chak 279/RB Kalan, Faisalabad',
#   1959: 'North Karachi - Sector 15A, Karachi',
#   449: 'Bypass Road, Muzaffargarh',
#   1622: 'MDA Chowk, Multan',
#   685: 'DHA Phase 6, Karachi',
#   1764: 'Model Town Coop Housing Society, Sialkot',
#   1466: 'Khanpur Adda, Rahimyar Khan',
#   153: 'Al Rehman Garden, Lahore',
#   1649: 'Main Canal Bank Road, Lahore',
#   1048: 'Gujrat - Sargodha Road, Bhalwal',
#   1726: 'Mehmoodabad, Karachi',
#   2323: 'Royal Residency, Multan',
#   784: 'E-16/1, Islamabad',
#   2149: 'Paragon City, Lahore',
#   343: 'Bahria Town Phase 2, Rawalpindi',
#   2605: 'Swabi, Khyber Pakhtunkhwa',
#   1561: 'Lahore, Punjab',
#   2446: 'Shadman 1, Lahore',
#   1365: 'Jinnah Residency, Karachi',
#   2450: 'Shadman Town, Lahore',
#   1343: 'Jhang Chiniot Road, Chiniot',
#   336: 'Bahria Town - Sector B, Lahore',
#   1254: 'IJP Road, Islamabad',
#   614: 'Civil Lines, Karachi',
#   546: 'Chan Da Qila, Gujranwala',
#   2321: 'Royal Orchard, Multan',
#   2075: 'Others, Sahiwal',
#   1712: 'Masjid Road, Quetta',
#   1168: 'Hafizabad Bypass, Hafizabad',
#   2496: 'Sham Nagar, Lahore',
#   2650: 'Theme Park View Society, Lahore',
#   1798: 'Moosa Goth, Karachi',
#   563: 'Chichawatni Burewala Road, Chichawatni',
#   2537: 'Sialkot - Bhagowal Road, Sialkot',
#   1422: 'Karachi Cantonment, Karachi',
#   1809: 'Mujahid Colony, Burewala',
#   196: 'Allama Iqbal Town - Ravi Block, Lahore',
#   1009: 'Ghulam Muhammad Town, Arifwala',
#   2522: 'Sher Shah Suri Road, Karachi',
#   1296: 'Jaffaria Colony, Lahore',
#   2090: 'Others, Yazman',
#   2600: 'Suraj Miani, Multan',
#   1441: 'Kassowal, Chichawatni',
#   2167: 'Peer Colony, Lahore',
#   27: 'Aara, Islamabad',
#   197: 'Allama Iqbal Town, Bahawalpur',
#   2490: 'Shalimar Colony, Multan',
#   553: 'Charsadda Road, Charsadda',
#   549: 'Chanman Abad, Rawalpindi',
#   577: 'Chowk Chohratha, Dera Ghazi Khan',
#   170: 'Ali Pur Chatta, Gujranwala',
#   2720: 'Wapda Town Phase 2, Lahore',
#   405: 'Big City, Sialkot',
#   33: 'Abbasia Bungalows, Rahimyar Khan',
#   357: 'Ballo Khaill Road, Mianwali',
#   640: 'Colony No 1, Khanewal',
#   662: 'DHA 11 Rahbar, Lahore',
#   1965: 'North Nazimabad - Block F, Karachi',
#   538: 'Chakra Road, Rawalpindi',
#   426: 'Block I, Burewala',
#   740: 'Dhok Chaudhrian, Rawalpindi',
#   1670: 'Manawan, Lahore',
#   1387: 'KRL Road, Rawalpindi',
#   305: 'Bagh-e-Bahisht, Sadiqabad',
#   1880: 'Nawa Killi Road, Quetta',
#   2038: 'Others, Jhang',
#   725: 'Delhi Mercentile Society, Karachi',
#   514: 'Chak 208 Road, Faisalabad',
#   2357: 'Safoora Goth, Karachi',
#   683: 'DHA Phase 5, Karachi',
#   1611: 'Luddan Road, Burewala',
#   678: 'DHA Phase 2, Karachi',
#   568: 'China Scheme, Lahore',
#   2066: 'Others, Okara',
#   834: 'Faisal Town, Lahore',
#   1405: 'Kalabagh, Mianwali',
#   2241: 'RJ Shopping Mall, Karachi',
#   1576: 'Landhi 2, Karachi',
#   774: 'Drigh Colony, Karachi',
#   1535: 'LDA Avenue, Lahore',
#   520: 'Chak 79 NB, Sargodha',
#   108: 'Aisha Manzil, Karachi',
#   392: 'Bhara kahu, Islamabad',
#   1808: 'Muhafiz Town, Gujranwala',
#   1102: 'Gulistan-e-Jauhar Block 3, Karachi',
#   2744: 'Yaseenabad, Karachi',
#   891: 'Ferozpur Road, Kasur',
#   583: 'Chungi Amar Sadhu, Lahore',
#   711: 'Daultala, Rawalpindi',
#   1260: 'Imdad Colony, Hujra Shah Muqeem',
#   171: 'Ali Pur, Islamabad',
#   872: 'Fatehpur, Layyah',
#   540: 'Chakri Road, Rawalpindi',
#   269: 'Audit & Accounts Phase 1, Lahore',
#   2672: 'Tulamba Road, Mian Chunnu',
#   2511: 'Shehzad Town, Islamabad',
#   879: 'Federal B Area - Block 14, Karachi',
#   1424: 'Karakoram Highway, Abbottabad',
#   1114: 'Gulraiz Housing Scheme, Rawalpindi',
#   573: 'Chobara Road, Layyah',
#   1172: 'Haidery, Karachi',
#   48: 'Abdara, Peshawar',
#   613: 'Civil Lines, Jhang',
#   184: 'Allahabad Road, Liaquatpur',
#   2619: 'Takht Bhai Bazar, Mardan',
#   369: 'Barki Road, Lahore',
#   1285: 'Istaqlalabad Colony, Sargodha',
#   2492: 'Shalimar Link Road, Lahore',
#   182: 'Alipur Farash, Islamabad',
#   2286: 'Rawalpindi, Punjab',
#   1518: 'Kot Addu, Punjab',
#   1945: 'Nisata Road, Mardan',
#   1075: 'Gulberg, Lahore',
#   2624: 'Tandlianwala Town, Faisalabad',
#   883: 'Federal B Area - Block 21, Karachi',
#   996: 'Ghauri Town Phase 4A, Islamabad',
#   1647: 'Main Boulevard DHA Defence, Lahore',
#   1968: 'North Nazimabad - Block M, Karachi',
#   473: 'Canal View, Okara',
#   442: 'Burewala Road, Arifwala',
#   2476: 'Shahi Road, Rahimyar Khan',
#   1074: 'Gulberg, Islamabad',
#   1929: 'New Mirpur City, Mirpur',
#   1633: 'Madina Syedan, Gujrat',
#   2318: 'Royal 8 Icon, Karachi',
#   2219: 'Qasimabad Phase 1, Hyderabad',
#   1624: 'MDA Road, Multan',
#   1873: 'Naval Anchorage, Islamabad',
#   88: 'Ahsan Colony, Multan',
#   1671: 'Manchinabad Road, Bahawalnagar',
#   639: 'College Road, Sialkot',
#   2678: 'Ugoke Road, Sialkot',
#   249: 'Askari 11, Rawalpindi',
#   938: 'GT Road, Fateh Jang',
#   1096: 'Gulistan-e-Jauhar Block 16, Karachi',
#   2432: 'Sea View Apartments, Karachi',
#   1317: 'Jamrao Head, Sanghar',
#   2233: 'Quaidabad, Karachi',
#   2626: 'Tank Road, Dera Ismail Khan',
#   1012: 'Gizri Road, Karachi',
#   909: 'G-12, Islamabad',
#   1327: 'Jandiala Road, Sheikhüpura',
#   1626: 'MET 2, Lahore',
#   207: 'Amangarh, Nowshera',
#   2055: 'Others, Mardan',
#   704: 'Darvesh, Haripur',
#   558: 'Chawinda, Sialkot',
#   2027: 'Others, Gujar Khan',
#   319: 'Bahawalpur Bypass, Bahawalpur',
#   1070: 'Gulberg Road, Bahawalpur',
#   1046: 'Gujranwala, Punjab',
#   1182: 'Hameedpura, Lahore',
#   204: 'Altaf Colony, Lahore',
#   2254: 'Rail Town (Canal City), Lahore',
#   1474: 'Kharian, Punjab',
#   331: 'Bahria Orchard, Lahore',
#   1438: 'Kashmir Road, Karachi',
#   2595: 'Super Highway, Karachi',
#   803: 'Elam Din Block, Lahore',
#   1269: 'Iqbal Town, Dina',
#   2609: 'TDA Colony, Layyah',
#   169: 'Ali Park, Lahore',
#   1575: 'Landhi 1, Karachi',
#   302: 'Badami Bagh, Lahore',
#   1253: 'IEP Engineers Town, Lahore',
#   1747: 'Mirpur Khas to Umarkot Road, Mirpur Khas',
#   651: 'D Type Colony, Faisalabad',
#   1761: 'Model Town A, Bahawalpur',
#   2168: 'Peer Khurshed Colony, Multan',
#   1585: 'Latifabad Unit 10, Hyderabad',
#   1199: 'Hasilpur, Punjab',
#   2636: 'Tarlai, Islamabad',
#   617: 'Civil Quarters, Peshawar',
#   1218: 'Hayatabad, Peshawar',
#   895: 'Formanites Housing Scheme, Lahore',
#   137: 'Al Jalil Garden - Block J, Lahore',
#   1587: 'Latifabad Unit 6, Hyderabad',
#   2465: 'Shahabpura, Sialkot',
#   1031: 'Grand City Faisalabad, Faisalabad',
#   1042: 'Green Town, Quetta',
#   1434: 'Kashmir Colony No 2, Gujranwala',
#   1698: 'Maqboolabad Society, Karachi',
#   1635: 'Madina Town, Faisalabad',
#   946: 'GT Road, Kharian',
#   1784: 'Mohalla Sufipura, Mandi Bahauddin',
#   1358: 'Jhumra Road, Faisalabad',
#   2324: 'Rustam Park, Lahore',
#   2499: 'Shamasabad, Gujranwala',
#   2712: 'Walton Road, Lahore',
#   1755: 'Model City 2, Faisalabad',
#   131: 'Al Hamra Society, Karachi',
#   262: 'Askari, Lahore',
#   2558: 'Sitara Sapna City, Faisalabad',
#   2019: 'Others, Chishtian Sharif',
#   1203: 'Hassan Town, Lahore',
#   1432: 'Karor Lal Esan, Layyah',
#   351: 'Baidra Road, Mansehra',
#   1270: 'Iqbal Town, Faisalabad',
#   136: 'Al Huda Town, Islamabad',
#   130: 'Al Hafeez Gardens, Lahore',
#   1616: 'Lyllapur Villas, Faisalabad',
#   668: 'DHA Defence Phase 2, Islamabad',
#   1006: 'Ghous-e-Azam Road, Rawalpindi',
#   833: 'Faisal Town, Faisalabad',
#   2376: 'Salli Town, Lahore',
#   2675: 'UET Housing Society, Lahore',
#   489: 'Cantt, Multan',
#   944: 'GT Road, Jhelum',
#   1177: 'Hajipura Road, Sialkot',
#   212: 'Ameen Town, Khanewal',
#   2516: 'Sheikhupura Fort Road, Sheikhüpura',
#   188: 'Allahwala Town, Karachi',
#   1551: 'Lahore Medical Housing Society, Lahore',
#   2067: 'Others, Pakpattan',
#   2754: 'Zaitoon Colony, Lahore',
#   2425: 'Scheme 33 - Sector 31, Karachi',
#   2466: 'Shahbaz Khan Road, Kasur',
#   2480: 'Shahkot Road, Nankana Sahib',
#   822: 'F-7, Islamabad',
#   2378: 'Samanabad, Faisalabad',
#   2536: 'Shumali Mohalla Road, Jhelum',
#   618: 'Clifton - Block 2, Karachi',
#   2464: 'Shahabpura Road, Sialkot',
#   1717: 'Mathra, Peshawar',
#   635: 'College Road, Lahore',
#   1864: 'Nasheman-e-Iqbal Phase 1, Lahore',
#   416: 'Bin Qasim Trade Centre, Karachi',
#   2741: 'Yaqubi Road, Swabi',
#   485: 'Cantt, Karachi',
#   2122: 'Pak Avenue Colony, Sahiwal',
#   2305: 'Riaz ul Jannah, Faisalabad',
#   1022: 'Golf View Residencia, Lahore',
#   2095: 'PAF Road, Mianwali',
#   2115: 'Pahar Ganj, Karachi',
#   1799: 'Morgah, Rawalpindi',
#   2716: 'Wapda Colony, Multan',
#   744: 'Dhok Gujran, Rawalpindi',
#   2402: 'Sargodha Road, Faisalabad',
#   1896: 'Nazimabad, Faisalabad',
#   724: 'Delhi Gate Multan, Multan',
#   1837: 'Muslim Gunj, Sheikhüpura',
#   1521: 'Kot Khawaja Saeed, Lahore',
#   873: 'Fatima Jinnah Road, Sargodha',
#   286: 'Aziz Bhatti Road, Lahore',
#   1534: 'Kurri Road, Rawalpindi',
#   35: 'Abbasia Town, Rahimyar Khan',
#   2385: 'Samundari Road, Faisalabad',
#   885: 'Federal B Area - Block 7, Karachi',
#   1414: 'Kamra Road, Attock',
#   337: 'Bahria Town - Sector C, Lahore',
#   1380: 'Judicial Colony, Lahore',
#   1536: 'LDA Quarters, Lahore',
#   1363: 'Jinnah Gardens, Islamabad',
#   1275: 'Islamabad Capital Territory, Pakistan',
#   1730: 'Metrovil Colony, Karachi',
#   2667: 'Township - Sector B1, Lahore',
#   253: 'Askari 2, Sialkot',
#   1315: 'Jamilabad, Taxila',
#   9: '29 Block, Sargodha',
#   1058: 'Gulbai, Karachi',
#   1237: 'Hyderabad - Badin Road, Tando Muhammad Khan',
#   414: 'Bilal Town, Jhelum',
#   2538: 'Sialkot Bypass, Gujranwala',
#   2502: 'Shams Abad, Rawalpindi',
#   2099: 'PCSIR Society Phase 2, Lahore',
#   1694: 'Mansoorah, Lahore',
#   2629: 'Tarbela Road, Hazro',
#   898: 'Fortress Stadium, Lahore',
#   882: 'Federal B Area - Block 17, Karachi',
#   1335: 'Jawad Avenue, Okara',
#   631: 'College Road, Bahawalnagar',
#   13: '505 EB Road, Burewala',
#   1695: 'Manthar Road, Sadiqabad',
#   1155: 'Guru Mandir Chorangi, Karachi',
#   2264: 'Raiwind Road, Lahore',
#   2442: 'Shadab Colony, Bahawalpur',
#   2713: 'Wapda City, Faisalabad',
#   412: 'Bilal Nagar, Faisalabad',
#   471: 'Canal Road, Toba Tek singh',
#   1488: 'Khudadad Colony, Karachi',
#   995: 'Ghauri Town Phase 2, Islamabad',
#   1081: 'Gulgasht Colony, Multan',
#   1947: 'Nishat Park, Sialkot',
#   211: 'Ameen Town - Phase 2, Dera Ghazi Khan',
#   1: '100 Feet Road, Bahawalpur',
#   814: 'F-11, Islamabad',
#   2366: 'Saidpur Road, Rawalpindi',
#   2755: 'Zakariya Town, Multan',
#   1716: 'Mateen Garden, Lahore',
#   1336: 'Jawad Club Road, Faisalabad',
#   1089: 'Gulistan-e-Jauhar Block 1, Karachi',
#   2032: 'Others, Haripur',
#   1220: 'Hazoori Bagh Road, Multan',
#   2481: 'Shahpur Kanjra, Lahore',
#   2012: 'Others, Bhalwal',
#   788: 'E-8, Islamabad',
#   2611: 'TIP Housing Society, Haripur',
#   2031: 'Others, Harappa',
#   718: 'Defence Road, Lahore',
#   2131: 'Pakpattan Road, Depalpur',
#   1689: 'Mankera, Bhakkar',
#   2011: 'Others, Bhakkar',
#   2120: 'Pak Arab Housing Society Phase 2, Lahore',
#   1044: 'Gujranwala Bypass, Gujranwala',
#   2304: 'Revenue Society - Block A, Lahore',
#   1019: 'Gojra to Toba Tek Singh Road, Toba Tek singh',
#   1481: 'Khayaban-e-Amin - Phase 1, Lahore',
#   2230: 'Quaid-e-Azam Colony, Rawalpindi',
#   1758: 'Model Colony, Karachi',
#   316: 'Bahawalnagar Bypass Road, Arifwala',
#   693: 'Dagi Road, Swabi',
#   2593: 'Sunehri Masjid Road, Peshawar',
#   1146: 'Gulshan-e-Umair, Karachi',
#   2325: 'Ryaz ul Jannah, Faisalabad',
#   2309: 'Ring Road, Peshawar',
#   6: '2/4-L Road, Okara',
#   365: 'Bannu Road, Kohat',
#   2310: 'Risalpur Town, Nowshera',
#   1071: 'Gulberg Town, Karachi',
#   917: 'G-15, Islamabad',
#   907: 'G-11/3, Islamabad',
#   ...},
#  'Description': {7369: "it's 2021 model fresh import, perfect engine suspension,non accidented,push start ,fully loaded car,need to sell urgently.",
#   5080: 'Suzuki ravi 2018 col ',
#   4993: 'Suzuki bolan model 2015 reg 2022 ghadi me koi Kam nai a',
#   3970: 'Move Push start \nHome Used car. \nModel 2013. \nRegistered in 2015. \nAll origina documents with smart card. \nTotal Geniune few touch ups. \nNever been into any major accident.',
#   4853: 'Suzuki Swift DLX\nAbS Break 100%\nengine 100%\nsuspension 100% \nAndroid panel\nbrand new tyer \n2/3 piece Touchups\nall documents clear\ncplc Clear \nno work required\ncontact no:0/3/3/2/3/0/9/6/0/7/1',
#   8716: 'wagon r total genuine AGS new tyre ',
#   6195: 'bilkul okay condition me hen engine change hen recently change karvaya hen book pe update nhe ha ',
#   4328: 'SUZUKI BOLANSuzuki Bolan 2016 genuine condition low mileage',
#   711: 'A very well maintained  - Good consumption\nno mechanical work, Excellent condition \ncomplete ,Engine perfect orginal condition car. .  \njust buy and drive daily driven smooth car  \noriginal condition Registered In Personal Name   \nNeat and clean interior - Each and every thing is mentioned     \nonly contact for serious buyers -\nNo silly offers good fuel average \nVery good Condition. \n10/10 condition ok    \nGenuine Condition. Price slightly negotiable. \n\n-Honda City 2004 Model    \n-MODEL: 2004 Registration : 2004\n-MILAGE DRIVEN:  ',
#   964: 'Ander s hotel janvan Hain by Matrek avlebal Hain new tair new batre',
#   4746: 'Suzuki Every \nModel 2012 Import 2018\nFully Genion \nWhite Color , New Leather Seats and Music',
#   870: 'Alloy rim \nnew tyre\nchat bunnet degi in genion paint\nsides p touching\nEngine 100%\nac heater 100%\napny engine m ha or pack ha\nM boofer and android installed\ngear hisa 100%\nNo work required gaurenty',
#   4653: "Suzuki Baleno sports Addition\nModel. 2004\nCool Bach color \n2nd owner\nJust Minor TouchUp 80% original\nOriginal milage only 1,40,00,0 drive on patrol \nOne powerful engine and soundless 10/10 \nSmooth suspension 10/10 \nOriginal Company rims new Tyler's\nFuel only patrol average Masha Allah 15 with Ac on the highway\nPower Window\nPower staring Smooth\nPower looks \nAc child \nNew site's covers install\nLCD and speakers VIP music system\nDrive like new car \nall dacomints are clear\nCplc 10/10 \nnumber plats 10/10 \ntikly original 10/10\nNo any minor work request\nJust by an drive smooth car \nNote 8,70 already offer available serious Bayer can contact and more video pics available on WhatsApp  ",
#   8848: 'ہونڈا سٹی 2006 auto  اے سی ہیٹر اوکے پٹرول ایوریج 15/16 سندھ نمبر تمام ڈاکومنٹس کلئیر ٹوکن لائف ٹائم گاڑی اکسیڈنٹ نئی ھے انجن سو فیصد اوکے گارنٹی\n فریش لک کے لئے باہر سے شاور اندر جینئین \n ٹائر 10/9 \nگاڑی ہر لحاظ سے بالکل اوکے',
#   1951: 'Dhaihatsu Move \nModel 2021\nimport September 2023\npush start\nclimate control\nAlloy Rims. \nRadar,\nseat heater\nand many more\nTotal genuine\noriginal milage\nwill be sold on nearest offer',
#   6994: 'good condition\nnon accidentally\nalloy wheels\noriginal file with smart card\nbio matric available\nengine is normal condition\nfamily usage car\nnew battery install',
#   3975: 'Move custom full option,\n2013 model 2017 registered,\nEngine suspension perfect,\nnon-accidental seal are ok,\nfew paint touchups in sides rest original. \ncar can be seen in dha Lahore phase 1.',
#   3104: 'Honda reborn prismatic\nModel 2007\nChat bonet diggi original\nLed back camera alloy wheels fog light sports body kit lagi hoi hai\nAc engine & suspension 100% ok\nGari main 1 rupay ka bhi kam nahi. \nLocation sadiqabad \njust buye and drive',
#   8309: 'suzuki cultus 2006 model Lahore registered. my own name biometric available. all documents clear smart card. old book available. lifetime token update. out side little shower inside totally original seal by seal. Ac Heather working. power steering. front suspension engine gear shokes original. all is best. seat is very good. new battery install 60 amr. Led panel 10 inch install. Center locking. Back camera install. allow rims .  tires 70 persent. only bay and drive. not have any work. Petrol average 15/17. whatsaap ',
#   6234: 'brand new car just buy n drive fully fresh car not a single work required chill ac    engine suspension gear   100 percent ok',
#   615: '2500 cc Honda civic vti-oriel 1.8 power',
#   5626: 'Toyota Xli\nModel 2008\nRegistration Lahore\nBiometric available\nAll documents available\nAll token taxes paid\nCondition:-\nRoof\nTrunk\nPiller\nBonet is in genuine condition\nNon accidental',
#   5913: 'Wogan R 2014 VXL Very well maintained Excellent condition 100%\n\n non accident',
#   8842: 'گاڑی ایسے کہ بلکل نئی کڈیشن',
#   104: '*TOYOTA COROLLA ALTIS 1.6 AUTOMATIC TRANSMISSION*\nMODEL:2019\nBUMPER TU BUMPER ORIGINAL \nDEMAND:4,475,000\nFIRST OWNER CAR \nGLASS COTING\n\nThrough out maintain from Toyota Low mileage Petrol driven TV navigation back view camera Excellent condition hids EXTRA ORDINARY CONDITION  smells like brand new car CRYSTAL clear documents tax upto date  Original manual books each and every thing available yet thorough out maintain car!! Visiting place Karachi.',
#   6419: 'chat diigi pillar geniun\ninside total geniun\noutar shower for fresh look\nnon accidental \ntyre 100 percent \nengine 100 percent \njust buy and drive\nprice is negotiable \ncontact no ',
#   2983: 'Honda city aspire\nmodel 2021\ncondition 10/10\ncolour black\n1500cc\nbumber to bumber genuine\nonly serious buyers\nprice final hai',
#   7992: 'petrol , ac genuine non accidental',
#   4231: 'Phone Number ',
#   2851: 'Honda Civic Reborn 2009 Automatic black color. \nHard top\nAlloy Rims 17" with low profile tyres. \nneat and clean car. \nall original, no touchups. \n no foolish offers please. \nCall if you want to visit or else message on watsapp better to avoid time wasting for  both of us please. \nPLEASE DO NOT COMPARE RATES WITH OTHERS \nTHANKS',
#   3864: 'Mitsubishi Meni pajero \n* model 1997\n* import 2007\n* original docoments\n* my name smart card\n* original return file number plats\n* vehicle all history available\n* 1100 cc power full engine\n* 6 speed gayer\n* 4×4 working \nAC working\n* 100% new Bridgestone original size tyre\n* alyre rim original 5 japani \n* LCD back camera\n* best feul average 1L 16/18\n* original power windows \n* original center locking\n* no accidental original condition Jeep \n* no work required buy and drive \nonly series buyers contact me gadi dakh\nkr offer Dan exchange possible ha achi car Suzuki mahran ya ravi k sath',
#   555: '2017 swift in silver genuine engine call me at this no ',
#   5595: 'Toyota Passo \nPearl White\n2015/18\nkm 55600\nnon accidental\nbumper to bumper original\nused as 2nd car\nchilled ac\nclimate control\nabs \nair bag\ndry battery \nused under government officer for office use\n\ninterested buyers contact, brokers and timewaster stayaway \n\nM Aslam',
#   490: '2013 city gun metallic total original sides slightly touchups due to scratches. \nmore or less car is in family use brand new tyres transmission oil just changed engine perfectly fine. new seat covers. \nbrand new android Led with back camera.',
#   3449: 'Isb reg   civic reborn led panel installed. \nManual. Sunroof',
#   3545: 'Kia Picanto Automatic,First owner, 14600 KMs Excellent Condition with all original fittings Lahore Regn with power steering n windows n as good as new.',
#   8138: 'selling coure 2007 model engine ok allow rims only need ac gas just buy and drive',
#   6035: 'all the parts are januane\nnon accidental\nneet and clean \nno work required',
#   6261: 'bumper to bumper geniun. . engine condition is new. . . . . first hand used. . . original document. . . like new car. . buy and drive. . . interior and seats very good like new. . . . 46000 km only drive. . . . price negociable. . . contact. . . faisal on this number. . . . 0/3/0/0/4/7/2/6/0/0/5. . . . urgent sale. . . . .',
#   4630: 'Suzuki Alto vxr\n2012 model\n1st owner\nSealed own powerful Engine \nThough out petrol driver \nCng never installed original petrol. \nSmooth soft drive \nManual transmission Perfect gear shifting \nAc chilled working condition \nSuspension 100%\nInside 100% Original Paint \nSeal by seal Genuine Inside \nOutside body 2 pis touch-up. \nAll documents file complete \nTak uptodate Dec 2023\nNote. Family use car \nPrice negotiable',
#   3530: 'Karwaan Plus Family used never use on transport purpose. \nnever go outside karachi. \n27k Km driven. \n\n1st owner. \n\nCPLC cleared all file documents available. both keys available. \nMaintained by Changan dealership zero work required. \n100% ok just like a new car. \nComplete original file is available. \nTotally driven on petrol. \nIn showroom condition. \nNever been into any accident. \nAll taxes paid UpTo date.',
#   3325: 'I want to sale my Suzuki swift mint condion just buy and drive',
#   6384: 'cash ki jarurat hai isliye sel karni hai',
#   1132: 'Baleno 2005 model with Total Japanese Accessories Installed Lash condition Original Smart card My own Name No Any work required just buy and Drive only  sides showered for fresh look One Hand use Car . . . . Totally car looks sports car seal to seal genuine car please only serous person contact Thank you',
#   7729: 'new condition dual ac fog lights (no work required) new tires no teaching\nplease serious people contact me ',
#   3799: 'Mira G smart Package\nColour Silver. \nModel 2013/2015. \nMileage 60,000 km approx. \nAssembly changed. \nFew pieces touchup. \nNon Accidental Car \npowerful suspension. \nall features work properly. ALL DOCUMENTS cleared and available. \nHID Installed\nFog lights Installed\nAndroid Panel Installed with \nrotating Back camera also featured\nCar cover Available\nrecently Oil changed. After Market Alloy rims.',
#   6912: 'gari bilkul ok ha charoo tarf sy shower ha',
#   925: 'Alto VXL Ags for Sale\nModel:2023\nMilage:15000\nDemand: 29Lakh\nLocation: Purani Lakar Mandi Okara\nTotal Genuine',
#   1790: 'Daihatsu Mira 2011/2015\n\nTotal Genuine \nOriginal Documents \n1st owner \n79000 km driven \nNew tyres \nMechanically fit car. \n\nWill be sold to nearest offer.',
#   8286: 'suzuki bolan 2014 model for sale condition all ok no any major accidents only some piece showered for fresh look inner genuine totallyy just buy and drive engine ok',
#   4323: 'SUZUKI ALTO VXR 2003. LAST MONTH\nFULLY ORIGINAL CONDITION. \nOWN POWERFUL ENGINE. \nCHILLED A/C. \nNO WORK REQUIRED.',
# ...
#   223: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows, USB and Auxillary Cable',
#   2125: 'ABS, Air Bags, Air Conditioning, Front Speakers, Power Locks, Power Steering, Power Windows, USB and Auxillary Cable',
#   5038: 'Air Conditioning, Alloy Rims, CD Player, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear speakers, Rear Camera',
#   5735: 'Alloy Rims, Keyless Entry, Rear AC Vents',
#   117: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, Cassette Player, Cruise Control, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   4577: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Power Locks, Power Mirrors, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   4075: 'Air Conditioning, AM/FM Radio, CD Player, Cool Box, DVD Player, Front Speakers, Power Locks, Power Steering, Power Windows',
#   368: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   1198: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Locks, Power Steering, Power Windows',
#   921: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   5274: 'Air Conditioning, CD Player, Power Locks, Power Steering',
#   502: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Front Speakers, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   2694: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Keyless Entry, Rear speakers',
#   5709: 'Alloy Rims, Front Speakers',
#   4991: 'Air Conditioning, Alloy Rims, AM/FM Radio, Power Windows',
#   2900: 'ABS, Air Conditioning, Alloy Rims, DVD Player, Front Speakers, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear Seat Entertainment, Rear speakers, Rear Camera',
#   3757: 'Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows',
#   3335: 'AM/FM Radio, Front Speakers, Rear AC Vents, Rear speakers, USB and Auxillary Cable',
#   1985: 'ABS, Air Bags, Air Conditioning, CD Player, Climate Control, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows, USB and Auxillary Cable',
#   5025: 'Air Conditioning, Alloy Rims, CD Player, Front Speakers, Keyless Entry, Navigation System, Rear speakers, USB and Auxillary Cable',
#   4277: 'Air Conditioning, AM/FM Radio, DVD Player, Front Speakers, USB and Auxillary Cable',
#   3949: 'Air Bags, Alloy Rims, AM/FM Radio, Power Locks, Power Windows, Rear speakers, USB and Auxillary Cable',
#   217: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   771: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   2746: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Front Camera, Heated Seats, Keyless Entry, Power Locks, Power Windows, Rear AC Vents, Rear speakers, USB and Auxillary Cable',
#   3992: 'Air Bags, DVD Player, Power Steering, Power Windows',
#   5542: 'Alloy Rims, AM/FM Radio, CD Player, Power Steering, Power Windows',
#   3290: 'AM/FM Radio, Cool Box, Front Speakers, USB and Auxillary Cable',
#   4496: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers',
#   2762: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   1261: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Navigation System, Power Locks, Power Mirrors, Power Windows, Rear speakers',
#   5932: 'Power Locks, Power Mirrors, Power Steering, Rear AC Vents, Rear speakers, USB and Auxillary Cable',
#   4711: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Keyless Entry',
#   2523: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Immobilizer Key, Keyless Entry, Rear speakers, USB and Auxillary Cable',
#   84: 'ABS, Air Bags, Air Conditioning, AM/FM Radio',
#   5304: 'Air Conditioning, DVD Player, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers',
#   2026: 'ABS, Air Bags, Air Conditioning, CD Player, Power Locks, Power Steering, Power Windows',
#   4450: 'Air Conditioning, AM/FM Radio, Power Windows, Rear speakers, USB and Auxillary Cable',
#   327: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, Front Speakers, Power Locks, Power Mirrors, Power Windows, Rear Camera',
#   531: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Front Speakers, Power Locks, Power Steering, Power Windows, USB and Auxillary Cable',
#   4840: 'Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows',
#   1704: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable',
#   2556: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Climate Control, Front Speakers, Power Mirrors, Power Steering, Power Windows, Rear Camera',
#   3063: 'ABS, Air Conditioning, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable',
#   1254: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Keyless Entry, Power Locks, Power Mirrors, Power Steering',
#   3135: 'ABS, Alloy Rims, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows',
#   3295: 'AM/FM Radio, DVD Player, Front Speakers',
#   438: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Front Speakers',
#   4037: 'Air Conditioning, AM/FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Power Locks, Rear speakers',
#   5698: 'Alloy Rims, Cool Box, Power Locks, Power Steering, Power Windows, Sun Roof',
#   5620: 'Alloy Rims, AM/FM Radio, Immobilizer Key',
#   788: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Steering, Power Windows, Rear speakers, Rear Camera',
#   3154: 'ABS, Alloy Rims, USB and Auxillary Cable',
#   4146: 'Air Conditioning, AM/FM Radio, CD Player, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Rear Camera, USB and Auxillary Cable',
#   80: 'ABS, Air Bags, AM/FM Radio, Power Mirrors, Power Steering, Power Windows, Sun Roof',
#   3594: 'Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cool Box, Cruise Control, DVD Player, Front Speakers, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   1453: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Cruise Control, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear speakers, Rear Camera, Sun Roof',
#   693: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Front Camera, Immobilizer Key',
#   4882: 'Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Navigation System, Power Locks, Power Steering, Power Windows, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   3780: 'Air Bags, Air Conditioning, Alloy Rims, CD Player, DVD Player, Front Speakers, Front Camera, Heated Seats, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   1945: 'ABS, Air Bags, Air Conditioning, Alloy Rims, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Windows, Rear Camera',
#   5185: 'Air Conditioning, Alloy Rims, Power Locks, Power Steering',
#   4756: 'Air Conditioning, Alloy Rims, AM/FM Radio, Cassette Player, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers',
#   1300: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   82: 'ABS, Air Bags, AM/FM Radio, Power Steering, Rear Camera, USB and Auxillary Cable',
#   52: 'ABS, Air Bags, AM/FM Radio, CD Player, Cool Box, DVD Player, Front Camera, Heated Seats, Rear speakers, Rear Camera, Steering Switches',
#   1869: 'ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Front Speakers, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   4460: 'Air Conditioning, AM/FM Radio, Rear speakers',
#   2155: 'ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Rear speakers, Rear Camera',
#   4455: 'Air Conditioning, AM/FM Radio, Rear AC Vents, Steering Switches, USB and Auxillary Cable',
#   1223: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable',
#   736: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, Cruise Control, Climate Control, Front Speakers, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   4701: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Front Speakers, USB and Auxillary Cable',
#   1664: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Power Steering, Rear Camera, USB and Auxillary Cable',
#   4950: 'Air Conditioning, Alloy Rims, AM/FM Radio, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   235: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, DVD Player, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear speakers, Rear Camera',
#   3651: 'Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Front Speakers, Keyless Entry, Power Locks, Power Steering, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   3625: 'Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, DVD Player, Front Speakers, Power Locks',
#   4579: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Power Locks, Power Steering, USB and Auxillary Cable',
#   5783: 'CD Player, DVD Player, Front Speakers',
#   803: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, DVD Player, Power Locks, Power Mirrors, Power Steering, USB and Auxillary Cable',
#   476: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Front Speakers, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera',
#   4563: 'Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, DVD Player, Front Speakers, Front Camera, Power Locks, Power Mirrors, Power Steering, Rear AC Vents, Rear speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   948: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cool Box, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear speakers, Steering Switches, USB and Auxillary Cable',
#   403: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Cruise Control, Power Steering',
#   5205: 'Air Conditioning, Alloy Rims, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   1089: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, DVD Player, Front Speakers, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   417: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, DVD Player, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Windows, Rear speakers',
#   3886: 'Air Bags, Air Conditioning, DVD Player, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera',
#   2082: 'ABS, Air Bags, Air Conditioning, Front Speakers',
#   1597: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, Front Speakers, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, Steering Switches, USB and Auxillary Cable',
#   5891: 'Front Speakers, Power Mirrors, Power Steering, Power Windows, Rear speakers, Sun Roof',
#   439: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Front Speakers, Front Camera, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows',
#   2641: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers',
#   376: 'ABS, Air Bags, Air Conditioning, AM/FM Radio, Climate Control, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, USB and Auxillary Cable',
#   666: 'ABS, Air Bags, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable',
#   5135: 'Air Conditioning, Alloy Rims, Front Speakers, Power Locks, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable',
#   2699: 'ABS, Air Conditioning, Alloy Rims, AM/FM Radio, CD Player, Power Steering, Power Windows, USB and Auxillary Cable',
#   2112: 'ABS, Air Bags, Air Conditioning, Front Speakers, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear Camera',
#   5217: 'Air Conditioning, CD Player, Cassette Player, Front Speakers, Rear speakers, Steering Switches',
#   ...}}
